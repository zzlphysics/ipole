# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({
    "font.family": "Times New Roman",
    "font.size": 8,        # 默认字体大小
    "axes.labelsize": 8,   # 轴标签字体大小
    "legend.fontsize": 8,  # 图例字体大小
    "mathtext.fontset": "stix",  # 数学字体设置为 STIX，这个与 Times New Roman 很接近
})

# %%
def read_test_data(file_path):
    """
    读取测试数据文件，并将数据转换为numpy数组
    
    参数:
        file_path (str): 测试数据文件的路径
        
    返回:
        tuple: 包含三个numpy数组 (sample_indices, predictions, labels)
    """
    # 读取数据
    data = pd.read_csv(file_path, sep=',', skipinitialspace=True)
    
    # 提取列数据
    sample_indices = data.iloc[:, 0].values
    predictions = data.iloc[:, 1].values
    labels = data.iloc[:, 2].values
    
    return sample_indices, predictions, labels

# %%
file_path = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_GRRT/a_0.920680.txt"
indices, preds, labels = read_test_data(file_path)

predictions = np.array(preds)
label_list = np.array(labels)

plt.figure(figsize=(8, 4))
plt.scatter(np.arange(len(predictions)), predictions, color='#015876', s=10, label='Predictions')  # s 控制点的大小
plt.scatter(np.arange(len(label_list)), label_list, color='#FDB137', s=10, label='Labels')  # s 控制点的大小
for i in range(len(predictions)):
    plt.plot([i, i], [predictions[i], label_list[i]], color='#C1D1D1', linestyle='-', linewidth=1)
plt.xlabel('sample')
plt.ylabel('number')
plt.ylim(-2.5, 2.5)
plt.legend()
plt.show()

# %%
grrt_a_file   = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_GRRT/a_0.920680.txt"
grrt_h_file   = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_GRRT/h_disk_0.984157.txt"
grrt_k_file   = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_GRRT/k_0.953897.txt"
grrt_mbh_file = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_GRRT/M_BH_0.998286.txt"
grrt_pa_file  = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_GRRT/PA_0.901279.txt"
grrt_te_file  = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_GRRT/T_e_0.967145.txt"

ddpm_a_file   = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_MIX/a_0.964585.txt"
ddpm_h_file   = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_MIX/h_disk_0.989320.txt"
ddpm_k_file   = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_MIX/k_0.976269.txt"
ddpm_mbh_file = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_MIX/M_BH_0.998251.txt"
ddpm_pa_file  = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_MIX/PA_0.960289.txt"
ddpm_te_file  = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_MIX/T_e_0.996019.txt"

# grrt_a_file   = "/root/Projects/ipole/output/riaf/job1/job_20250102/test2_result/GRRT/a_0.951123.txt"
# grrt_h_file   = "/root/Projects/ipole/output/riaf/job1/job_20250102/test2_result/GRRT/h_disk_0.986711.txt"
# grrt_k_file   = "/root/Projects/ipole/output/riaf/job1/job_20250102/test2_result/GRRT/k_0.963670.txt"
# grrt_mbh_file = "/root/Projects/ipole/output/riaf/job1/job_20250102/test2_result/GRRT/M_BH_0.998958.txt"
# grrt_pa_file  = "/root/Projects/ipole/output/riaf/job1/job_20250102/test2_result/GRRT/PA_0.917030.txt"
# grrt_te_file  = "/root/Projects/ipole/output/riaf/job1/job_20250102/test2_result/GRRT/T_e_0.969461.txt"

# ddpm_a_file   = "/root/Projects/ipole/output/riaf/job1/job_20250102/test2_result/MIX/a_0.980047.txt"
# ddpm_h_file   = "/root/Projects/ipole/output/riaf/job1/job_20250102/test2_result/MIX/h_disk_0.987236.txt"
# ddpm_k_file   = "/root/Projects/ipole/output/riaf/job1/job_20250102/test2_result/MIX/k_0.979223.txt"
# ddpm_mbh_file = "/root/Projects/ipole/output/riaf/job1/job_20250102/test2_result/MIX/M_BH_0.998653.txt"
# ddpm_pa_file  = "/root/Projects/ipole/output/riaf/job1/job_20250102/test2_result/MIX/PA_0.911330.txt"
# ddpm_te_file  = "/root/Projects/ipole/output/riaf/job1/job_20250102/test2_result/MIX/T_e_0.996590.txt"

# ddpm_a_file = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_DDPM/a_0.799253.txt"
# ddpm_h_file = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_DDPM/h_disk_0.968393.txt"
# ddpm_k_file = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_DDPM/k_0.915728.txt"
# ddpm_mbh_file = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_DDPM/M_BH_0.991304.txt"
# ddpm_pa_file = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_DDPM/PA_0.778930.txt"
# ddpm_te_file = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_gauss0_20250405/test_result_DDPM/T_e_0.979332.txt"

grrt_a_indices, grrt_a_preds, grrt_a_labels = read_test_data(grrt_a_file)
grrt_h_indices, grrt_h_preds, grrt_h_labels = read_test_data(grrt_h_file)
grrt_k_indices, grrt_k_preds, grrt_k_labels = read_test_data(grrt_k_file)
grrt_mbh_indices, grrt_mbh_preds, grrt_mbh_labels = read_test_data(grrt_mbh_file)
grrt_pa_indices, grrt_pa_preds, grrt_pa_labels = read_test_data(grrt_pa_file)
grrt_te_indices, grrt_te_preds, grrt_te_labels = read_test_data(grrt_te_file)

ddpm_a_indices, ddpm_a_preds, ddpm_a_labels = read_test_data(ddpm_a_file)
ddpm_h_indices, ddpm_h_preds, ddpm_h_labels = read_test_data(ddpm_h_file)
ddpm_k_indices, ddpm_k_preds, ddpm_k_labels = read_test_data(ddpm_k_file)
ddpm_mbh_indices, ddpm_mbh_preds, ddpm_mbh_labels = read_test_data(ddpm_mbh_file)
ddpm_pa_indices, ddpm_pa_preds, ddpm_pa_labels = read_test_data(ddpm_pa_file)
ddpm_te_indices, ddpm_te_preds, ddpm_te_labels = read_test_data(ddpm_te_file)

# %%
# 创建一个3行4列的图表布局
fig, axes = plt.subplots(3, 4, figsize=(6.8, 4.8), sharex=True, sharey=True, dpi=300)

# 定义数据和标题的映射
data_mapping = [
    # 第一行
    (grrt_a_indices, grrt_a_preds, grrt_a_labels, r"RLDs   $a$"),
    (ddpm_a_indices, ddpm_a_preds, ddpm_a_labels, r"MXDs   $a$"),
    (grrt_mbh_indices, grrt_mbh_preds, grrt_mbh_labels, r"RLDs   $M_{BH}$"),
    (ddpm_mbh_indices, ddpm_mbh_preds, ddpm_mbh_labels, r"MXDs   $M_{BH}$"),
    # 第二行
    (grrt_te_indices, grrt_te_preds, grrt_te_labels, r"RLDs   $T_e$"),
    (ddpm_te_indices, ddpm_te_preds, ddpm_te_labels, r"MXDs   $T_e$"),
    (grrt_k_indices, grrt_k_preds, grrt_k_labels, r"RLDs   $k$"),
    (ddpm_k_indices, ddpm_k_preds, ddpm_k_labels, r"MXDs   $k$"),
    # 第三行
    (grrt_h_indices, grrt_h_preds, grrt_h_labels, r"RLDs   $h$"),
    (ddpm_h_indices, ddpm_h_preds, ddpm_h_labels, r"MXDs   $h$"),
    (grrt_pa_indices, grrt_pa_preds, grrt_pa_labels, r"RLDs   $PA$"),
    (ddpm_pa_indices, ddpm_pa_preds, ddpm_pa_labels, r"MXDs   $PA$")
]

# 绘制每个子图
for i in range(3):
    for j in range(4):
        idx = i * 4 + j
        indices, preds, labels, title = data_mapping[idx]
        
        ax = axes[i, j]
        
        # 绘制连接线
        for k in range(len(indices)):
            ax.plot([indices[k], indices[k]], [preds[k], labels[k]], color='#C1D1D1', linestyle='-', linewidth=0.8, zorder=0)
        ax.scatter(indices, preds, color='#015876', s=1, label='Predictions', zorder=1)
        ax.scatter(indices, labels, color='#FDB137', s=1, label='Labels', zorder=1)
        
        # 在图内左上角添加标题，而不是使用set_title
        ax.text(0.05, 0.95, title, transform=ax.transAxes, fontsize=8, 
                verticalalignment='top', horizontalalignment='left')
        
        ax.set_ylim(-2.5, 2.5)
        
        # 只在左侧和底部子图添加标签
        if j == 0:
            ax.set_ylabel('Value')
        if i == 2:
            ax.set_xlabel('Sample')

# 添加图例（只在第一个子图添加）
handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 0.98), ncol=2)

# 减少子图之间的间距
plt.tight_layout()
plt.subplots_adjust(top=0.92, wspace=0.08, hspace=0.08)  # 减小wspace和hspace以减少图之间的距离
plt.savefig("fig7_plot.pdf", dpi=300)
plt.show()

# %%
grrt_a_file_gauss_10 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss10/GRRT/a_0.926335.txt"
grrt_h_file_gauss_10 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss10/GRRT/h_disk_0.971787.txt"
grrt_k_file_gauss_10 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss10/GRRT/k_0.975179.txt"
grrt_mbh_file_gauss_10 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss10/GRRT/M_BH_0.995009.txt"
grrt_pa_file_gauss_10 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss10/GRRT/PA_0.898190.txt"
grrt_te_file_gauss_10 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss10/GRRT/T_e_0.975695.txt"

ddpm_a_file_gauss_10 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss10/MIX/a_0.950928.txt"
ddpm_h_file_gauss_10 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss10/MIX/h_disk_0.973705.txt"
ddpm_k_file_gauss_10 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss10/MIX/k_0.977435.txt"
ddpm_mbh_file_gauss_10 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss10/MIX/M_BH_0.996288.txt"
ddpm_pa_file_gauss_10 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss10/MIX/PA_0.807064.txt"
ddpm_te_file_gauss_10 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss10/MIX/T_e_0.990111.txt"

grrt_a_indices_gauss_10, grrt_a_preds_gauss_10, grrt_a_labels_gauss_10 = read_test_data(grrt_a_file_gauss_10)
grrt_h_indices_gauss_10, grrt_h_preds_gauss_10, grrt_h_labels_gauss_10 = read_test_data(grrt_h_file_gauss_10)
grrt_k_indices_gauss_10, grrt_k_preds_gauss_10, grrt_k_labels_gauss_10 = read_test_data(grrt_k_file_gauss_10)
grrt_mbh_indices_gauss_10, grrt_mbh_preds_gauss_10, grrt_mbh_labels_gauss_10 = read_test_data(grrt_mbh_file_gauss_10)
grrt_pa_indices_gauss_10, grrt_pa_preds_gauss_10, grrt_pa_labels_gauss_10 = read_test_data(grrt_pa_file_gauss_10)
grrt_te_indices_gauss_10, grrt_te_preds_gauss_10, grrt_te_labels_gauss_10 = read_test_data(grrt_te_file_gauss_10)

ddpm_a_indices_gauss_10, ddpm_a_preds_gauss_10, ddpm_a_labels_gauss_10 = read_test_data(ddpm_a_file_gauss_10)
ddpm_h_indices_gauss_10, ddpm_h_preds_gauss_10, ddpm_h_labels_gauss_10 = read_test_data(ddpm_h_file_gauss_10)
ddpm_k_indices_gauss_10, ddpm_k_preds_gauss_10, ddpm_k_labels_gauss_10 = read_test_data(ddpm_k_file_gauss_10)
ddpm_mbh_indices_gauss_10, ddpm_mbh_preds_gauss_10, ddpm_mbh_labels_gauss_10 = read_test_data(ddpm_mbh_file_gauss_10)
ddpm_pa_indices_gauss_10, ddpm_pa_preds_gauss_10, ddpm_pa_labels_gauss_10 = read_test_data(ddpm_pa_file_gauss_10)
ddpm_te_indices_gauss_10, ddpm_te_preds_gauss_10, ddpm_te_labels_gauss_10 = read_test_data(ddpm_te_file_gauss_10)


grrt_a_file_gauss_20 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss20/GRRT/a_0.689316.txt"
grrt_h_file_gauss_20 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss20/GRRT/h_disk_-0.068308.txt"
grrt_k_file_gauss_20 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss20/GRRT/k_0.959892.txt"
grrt_mbh_file_gauss_20 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss20/GRRT/M_BH_0.958537.txt"
grrt_pa_file_gauss_20 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss20/GRRT/PA_0.841769.txt"
grrt_te_file_gauss_20 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss20/GRRT/T_e_0.902150.txt"

ddpm_a_file_gauss_20 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss20/MIX/a_0.773260.txt"
ddpm_h_file_gauss_20 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss20/MIX/h_disk_-0.332571.txt"
ddpm_k_file_gauss_20 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss20/MIX/k_0.964813.txt"
ddpm_mbh_file_gauss_20 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss20/MIX/M_BH_0.986562.txt"
ddpm_pa_file_gauss_20 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss20/MIX/PA_0.872639.txt"
ddpm_te_file_gauss_20 = "/root/Projects/ipole/output/riaf/job1/job_20250102/result_20250407/result_gauss20/MIX/T_e_0.979944.txt"

grrt_a_indices_gauss_20, grrt_a_preds_gauss_20, grrt_a_labels_gauss_20 = read_test_data(grrt_a_file_gauss_20)
grrt_h_indices_gauss_20, grrt_h_preds_gauss_20, grrt_h_labels_gauss_20 = read_test_data(grrt_h_file_gauss_20)
grrt_k_indices_gauss_20, grrt_k_preds_gauss_20, grrt_k_labels_gauss_20 = read_test_data(grrt_k_file_gauss_20)
grrt_mbh_indices_gauss_20, grrt_mbh_preds_gauss_20, grrt_mbh_labels_gauss_20 = read_test_data(grrt_mbh_file_gauss_20)
grrt_pa_indices_gauss_20, grrt_pa_preds_gauss_20, grrt_pa_labels_gauss_20 = read_test_data(grrt_pa_file_gauss_20)
grrt_te_indices_gauss_20, grrt_te_preds_gauss_20, grrt_te_labels_gauss_20 = read_test_data(grrt_te_file_gauss_20)

ddpm_a_indices_gauss_20, ddpm_a_preds_gauss_20, ddpm_a_labels_gauss_20 = read_test_data(ddpm_a_file_gauss_20)
ddpm_h_indices_gauss_20, ddpm_h_preds_gauss_20, ddpm_h_labels_gauss_20 = read_test_data(ddpm_h_file_gauss_20)
ddpm_k_indices_gauss_20, ddpm_k_preds_gauss_20, ddpm_k_labels_gauss_20 = read_test_data(ddpm_k_file_gauss_20)
ddpm_mbh_indices_gauss_20, ddpm_mbh_preds_gauss_20, ddpm_mbh_labels_gauss_20 = read_test_data(ddpm_mbh_file_gauss_20)
ddpm_pa_indices_gauss_20, ddpm_pa_preds_gauss_20, ddpm_pa_labels_gauss_20 = read_test_data(ddpm_pa_file_gauss_20)
ddpm_te_indices_gauss_20, ddpm_te_preds_gauss_20, ddpm_te_labels_gauss_20 = read_test_data(ddpm_te_file_gauss_20)

# %%
# 创建一个3行4列的图表布局
fig, axes = plt.subplots(6, 4, figsize=(6.8, 8.8), sharex=True, sharey=True, dpi=300)

# 定义数据和标题的映射
data_mapping = [
    # 第一行
    (grrt_a_indices_gauss_10, grrt_a_preds_gauss_10, grrt_a_labels_gauss_10, r"RLDs   $a$"),
    (ddpm_a_indices_gauss_10, ddpm_a_preds_gauss_10, ddpm_a_labels_gauss_10, r"MXDs   $a$"),
    (grrt_a_indices_gauss_20, grrt_a_preds_gauss_20, grrt_a_labels_gauss_20, r"RLDs   $a$"),
    (ddpm_a_indices_gauss_20, ddpm_a_preds_gauss_20, ddpm_a_labels_gauss_20, r"MXDs   $a$"),

    (grrt_mbh_indices_gauss_10, grrt_mbh_preds_gauss_10, grrt_mbh_labels_gauss_10, r"RLDs   $M_{BH}$"),
    (ddpm_mbh_indices_gauss_10, ddpm_mbh_preds_gauss_10, ddpm_mbh_labels_gauss_10, r"MXDs   $M_{BH}$"),
    (grrt_mbh_indices_gauss_20, grrt_mbh_preds_gauss_20, grrt_mbh_labels_gauss_20, r"RLDs   $M_{BH}$"),
    (ddpm_mbh_indices_gauss_20, ddpm_mbh_preds_gauss_20, ddpm_mbh_labels_gauss_20, r"MXDs   $M_{BH}$"),

    (grrt_te_indices_gauss_10, grrt_te_preds_gauss_10, grrt_te_labels_gauss_10, r"RLDs   $T_e$"),
    (ddpm_te_indices_gauss_10, ddpm_te_preds_gauss_10, ddpm_te_labels_gauss_10, r"MXDs   $T_e$"),
    (grrt_te_indices_gauss_20, grrt_te_preds_gauss_20, grrt_te_labels_gauss_20, r"RLDs   $T_e$"),
    (ddpm_te_indices_gauss_20, ddpm_te_preds_gauss_20, ddpm_te_labels_gauss_20, r"MXDs   $T_e$"),

    (grrt_k_indices_gauss_10, grrt_k_preds_gauss_10, grrt_k_labels_gauss_10, r"RLDs   $k$"),
    (ddpm_k_indices_gauss_10, ddpm_k_preds_gauss_10, ddpm_k_labels_gauss_10, r"MXDs   $k$"),
    (grrt_k_indices_gauss_20, grrt_k_preds_gauss_20, grrt_k_labels_gauss_20, r"RLDs   $k$"),
    (ddpm_k_indices_gauss_20, ddpm_k_preds_gauss_20, ddpm_k_labels_gauss_20, r"MXDs   $k$"),

    (grrt_h_indices_gauss_10, grrt_h_preds_gauss_10, grrt_h_labels_gauss_10, r"RLDs   $h$"),
    (ddpm_h_indices_gauss_10, ddpm_h_preds_gauss_10, ddpm_h_labels_gauss_10, r"MXDs   $h$"),
    (grrt_h_indices_gauss_20, grrt_h_preds_gauss_20, grrt_h_labels_gauss_20, r"RLDs   $h$"),
    (ddpm_h_indices_gauss_20, ddpm_h_preds_gauss_20, ddpm_h_labels_gauss_20, r"MXDs   $h$"),

    (grrt_pa_indices_gauss_10, grrt_pa_preds_gauss_10, grrt_pa_labels_gauss_10, r"RLDs   $PA$"),
    (ddpm_pa_indices_gauss_10, ddpm_pa_preds_gauss_10, ddpm_pa_labels_gauss_10, r"MXDs   $PA$"),
    (grrt_pa_indices_gauss_20, grrt_pa_preds_gauss_20, grrt_pa_labels_gauss_20, r"RLDs   $PA$"),
    (ddpm_pa_indices_gauss_20, ddpm_pa_preds_gauss_20, ddpm_pa_labels_gauss_20, r"MXDs   $PA$")
]

# 绘制每个子图
for i in range(6):
    for j in range(4):
        idx = i * 4 + j
        indices, preds, labels, title = data_mapping[idx]
        
        ax = axes[i, j]
        
        # 绘制连接线
        for k in range(len(indices)):
            ax.plot([indices[k], indices[k]], [preds[k], labels[k]], color='#C1D1D1', linestyle='-', linewidth=0.8, zorder=0)
        ax.scatter(indices, preds, color='#015876', s=1, label='Predictions', zorder=1)
        ax.scatter(indices, labels, color='#FDB137', s=1, label='Labels', zorder=1)
        
        # 在图内左上角添加标题，而不是使用set_title
        ax.text(0.05, 0.95, title, transform=ax.transAxes, fontsize=8, 
                verticalalignment='top', horizontalalignment='left')
        
        ax.set_ylim(-2.5, 2.5)
        
        # 只在左侧和底部子图添加标签
        if j == 0:
            ax.set_ylabel('Value')
        if i == 5:
            ax.set_xlabel('Sample')
        # if i == 0 and (j == 0 or j == 1):
        #     ax.set_title(r'Convolved with $10 \mu as$ FWHM Gaussian Beam', fontsize=6)
        # if i == 0 and (j == 2 or j == 3):
        #     ax.set_title(r'Blurred, $20 \mu as$')

# 添加图例（只在第一个子图添加）
handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 0.98), ncol=2)
fig.text(0.295, 0.94, r'Convolved with $10 \mu as$ FWHM Gaussian Beam', ha='center', va='top', fontsize=10)
fig.text(0.75, 0.94, r'Convolved with $20 \mu as$ FWHM Gaussian Beam', ha='center', va='top', fontsize=10)

# 减少子图之间的间距
plt.tight_layout()
plt.subplots_adjust(top=0.92, wspace=0.08, hspace=0.08)  # 减小wspace和hspace以减少图之间的距离
plt.savefig("fig8_plot.pdf", dpi=300)
plt.show()

# %%
# 创建画布
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(6.8, 2), dpi=300, sharex=True, sharey=True)

# ---------------------------
# 第一个混淆矩阵 (100%准确率)
# ---------------------------
cm1 = np.array([[98,   5],   # TN, FP
                [  15, 98]])  # FN, TP

# 可视化配置
im1 = ax1.imshow(cm1, cmap='Blues', vmin=0, vmax=120)
#ax1.set_title('MNIST (Acc: 100%)', fontsize=12, pad=15)
ax1.set_xticks([0, 1])
ax1.set_yticks([0, 1])
ax1.set_xticklabels(['-1', '+1'])
ax1.set_yticklabels(['-1', '+1'])
ax1.set_xlabel(r'Predicted $F_{\mathrm{dir}}$')
ax1.set_ylabel(r'True $F_{\mathrm{dir}}$')
ax1.set_title('RLDs')
# 添加数值标签
for i in range(2):
    for j in range(2):
        text_color = 'white' if cm1[i, j] > 50 else 'black'
        ax1.text(j, i, f'{cm1[i, j]}\n({cm1[i, j]/np.sum(cm1):.1%})',
                ha='center', va='center', 
                color=text_color,
                fontweight='bold' if (i != j) else 'normal')

# ---------------------------
# 第二个混淆矩阵 (99.02%准确率)
# ---------------------------
cm2 = np.array([[87,   16],   # TN, FP (负样本误判)
                [  5, 108]])  # FN, TP (正样本误判)

# 可视化配置
im2 = ax2.imshow(cm2, cmap='Blues', vmin=0, vmax=120)
#ax2.set_title('FashionMNIST (Acc: 99.02%)', fontsize=12, pad=15)
ax2.set_xticks([0, 1])
ax2.set_yticks([0, 1])
ax2.set_xticklabels(['-1', '+1'])
ax2.set_yticklabels(['-1', '+1'])
ax2.set_xlabel(r'Predicted $F_{\mathrm{dir}}$')
ax2.set_title('FKDs')
# 添加数值标签（突出显示错误分类）
for i in range(2):
    for j in range(2):
        text_color = 'white' if cm2[i, j] > 50 else 'black'
        ax2.text(j, i, f'{cm2[i, j]}\n({cm2[i, j]/np.sum(cm2):.1%})',
                ha='center', va='center', 
                color=text_color, 
                fontweight='bold' if (i != j) else 'normal')

# ---------------------------
# 第三个混淆矩阵 (85.55%准确率)
# ---------------------------
cm3 = np.array([[96,  7],   # TN, FP (负样本误判)
                [  4, 109]])  # FN, TP (正样本误判)

# 可视化配置
im3 = ax3.imshow(cm3, cmap='Blues', vmin=0, vmax=120)
#ax3.set_title('CIFAR-10 (Acc: 85.55%)', fontsize=12, pad=15)
ax3.set_xticks([0, 1])
ax3.set_yticks([0, 1])
ax3.set_xticklabels(['-1', '+1'])
ax3.set_yticklabels(['-1', '+1'])
ax3.set_xlabel(r'Predicted $F_{\mathrm{dir}}$')
ax3.set_title('MXDs')

# 添加数值标签（突出显示错误分类）
for i in range(2):
    for j in range(2):
        text_color = 'white' if cm3[i, j] > 50 else 'black'
        ax3.text(j, i, f'{cm3[i, j]}\n({cm3[i, j]/np.sum(cm3):.1%})',
                ha='center', va='center', 
                color=text_color,
                fontweight='bold' if (i != j) else 'normal')

# 添加颜色条
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # [left, bottom, width, height]
cbar = fig.colorbar(im3, cax=cbar_ax)
cbar.set_label('Sample Count', rotation=270, labelpad=15)

# 调整布局
plt.subplots_adjust(wspace=0.2, right=0.9)  # 调整子图间距和颜色条位置
plt.savefig('confusion_matrices.pdf', dpi=300, bbox_inches='tight')
plt.show()
